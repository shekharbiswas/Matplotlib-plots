# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib._color_data as mcd

# %%
df = pd.read_csv('columns_bar.csv')
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df[]
# Out:
#      col0      col1      col2      col3    col4      col5      col6      col7  \
# 0     Ind  0.000000  0.000000  0.000000  0.0000  0.000000  0.000000  0.000000
# 1     Mex  0.000000  0.000000  0.000000  0.0000  0.000000  0.000000  0.000000
# 2     Bra  0.000000  0.000000  0.000000  0.0000  0.000000  0.000000  0.000000
# 3      US  0.000000  0.000000  0.107605  0.0000  0.259695  0.547091  0.065789
# 4  Poland  0.311650  0.018664  0.000000  0.0000  0.000000  0.000000  0.017558
# 5      UK  0.007399  0.000000  0.000000  0.0037  0.000000  0.000000  0.000000
# 6   China  0.083571  0.000000  0.000000  0.0000  0.000000  0.000000  0.000000
# 7     Pak  0.000000  0.000000  0.000000  0.0000  0.000000  0.000000  0.000000
#
#        col8      col9  ...  col140    col141    col142    col143    col144  \
# 0  0.000000  0.000000  ...  0.0000  0.000000  0.000000  0.000000  0.000000
# 1  0.023639  0.000000  ...  0.0000  0.000000  0.000000  0.005893  0.000000
# ...

# %%
ax = df.plot(kind='bar', stacked=True, x = 'col0',figsize=(12, 12), fontsize=12, legend = False, color = mcd.CSS4_COLORS)

ax.set_xlabel("Country", fontsize = 18)
ax.set_ylabel("Observations", fontsize = 18)
ax.figure.savefig('barplot.png')

# %%
ax = df.plot(kind='bar', stacked=True, x = 'col0',figsize=(12, 12), fontsize=12, legend = True, color = mcd.CSS4_COLORS)

handles,labels = ax.get_legend_handles_labels()
plt.legend(fontsize='xx-large', ncol=5,handleheight=2.4, labelspacing=0.05)
fig_legend = plt.figure(figsize=(30,15))
axi = fig_legend.add_subplot(111)            
fig_legend.legend(handles, labels, loc='center', fontsize='xx-large', ncol=5,handleheight=2.4, labelspacing=0.05)
axi.xaxis.set_visible(False)
axi.yaxis.set_visible(False)
fig_legend.canvas.draw()
fig_legend.show()
fig_legend.savefig('legend.png')
